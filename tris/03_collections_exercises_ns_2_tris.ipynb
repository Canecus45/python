# %% [markdown]
# # Esercizi con le Collezioni #2

# %% [markdown]
# ## Gioco del tris ([risorsa](https://www.elexpo.net/archivio/sistemi/libro_automate_python/05.pdf))
#
#
# Completare il codice per ottenere una gestione della partita come idicato:

# %% [markdown]
# ![external-content.duckduckgo.com.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Schermata 2021-10-19 alle 19.00.46.png](data:image/png;base64,...)

# %% [markdown]
# Dovrai implementare funzioni per:
#
# 1.   Mostrare la scacchiera
# 2.   Controllare se una posizione è libera o occupata
# 3.   Controllare se un giocatore ha fatto Tris

# %%
# Dizionario che rappresenta la scacchiera con 9 posizioni, inizialmente libere
# mentre la partita si svolge il valore associato sarà o X oppure O
theBoard = {'top-L': ' ', 'top-M': ' ', 'top-R': ' ',
            'mid-L': ' ', 'mid-M': ' ', 'mid-R': ' ',
            'low-L': ' ', 'low-M': ' ', 'low-R': ' '}

def printBoard(board):
  pass

def controllaPosizione(board,posizione):
  pass

def controllaVittoria(board):
  pass

#stabilisce il turno iniziale
turn = 'X'

#ciclo per gestire le 9 mosse
for i in range(9):
    #stampa la scacchiera
    #gestisci input mossa
    #aggiorna dizionario
    #cambia turno
